# %% [markdown]
# # Computer Vision Tutorial
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
#
# ### 1. Load CIFAR-10 Database

# %%
from tensorflow import keras
from tensorflow.keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255
# In fact, the cost function has the shape of a bowl, but it can be an elongated bowl if the features have very
# different scales. Figure below shows Gradient Descent on a training set where features 1 and 2 have the
# same scale (on the left), and on a training set where feature 1 has much smaller values than feature 2 (on
# the right).
#
# ** Tip: ** When using Gradient Descent, you should ensure that all features have a similar scale to speed up training or else it will take much longer to converge.
#
# ![feature scaling](normalized.jpg)

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
# from tensorflow.keras.utils import

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture
#
# ![feature scaling](cnn-schema1.jpg)

# %%
from  tensorflow.keras.models import Sequential
from  tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, save_best_only=True)

hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Epoch 1/100
# 1407/1407 - 5s - loss: 1.6090 - accuracy: 0.4172 - val_loss: 1.4190 - val_accuracy: 0.4880
#
# Epoch 00001: val_loss improved from inf to 1.41896, saving model to model.weights.best.hdf5
# Epoch 2/100
# 1407/1407 - 3s - loss: 1.2794 - accuracy: 0.5456 - val_loss: 1.1483 - val_accuracy: 0.5904
#
# Epoch 00002: val_loss improved from 1.41896 to 1.14825, saving model to model.weights.best.hdf5
# Epoch 3/100
# 1407/1407 - 3s - loss: 1.1613 - accuracy: 0.5907 - val_loss: 1.0719 - val_accuracy: 0.6198
#
# Epoch 00003: val_loss improved from 1.14825 to 1.07189, saving model to model.weights.best.hdf5
# Epoch 4/100
# 1407/1407 - 3s - loss: 1.0970 - accuracy: 0.6129 - val_loss: 1.1792 - val_accuracy: 0.5944
#
# Epoch 00004: val_loss did not improve from 1.07189
# Epoch 5/100
# 1407/1407 - 3s - loss: 1.0536 - accuracy: 0.6320 - val_loss: 1.0031 - val_accuracy: 0.6476
#
# Epoch 00005: val_loss improved from 1.07189 to 1.00309, saving model to model.weights.best.hdf5
# Epoch 6/100
# 1407/1407 - 3s - loss: 1.0268 - accuracy: 0.6466 - val_loss: 0.9474 - val_accuracy: 0.6768
#
# Epoch 00006: val_loss improved from 1.00309 to 0.94736, saving model to model.weights.best.hdf5
# Epoch 7/100
# 1407/1407 - 3s - loss: 1.0098 - accuracy: 0.6521 - val_loss: 1.0800 - val_accuracy: 0.6324
#
# Epoch 00007: val_loss did not improve from 0.94736
# Epoch 8/100
# 1407/1407 - 3s - loss: 0.9989 - accuracy: 0.6555 - val_loss: 0.9754 - val_accuracy: 0.6808
#
# Epoch 00008: val_loss did not improve from 0.94736
# Epoch 9/100
# 1407/1407 - 3s - loss: 0.9960 - accuracy: 0.6560 - val_loss: 1.6580 - val_accuracy: 0.5310
#
# Epoch 00009: val_loss did not improve from 0.94736
# Epoch 10/100
# 1407/1407 - 3s - loss: 0.9993 - accuracy: 0.6607 - val_loss: 0.9726 - val_accuracy: 0.6788
#
# Epoch 00010: val_loss did not improve from 0.94736
# Epoch 11/100
# 1407/1407 - 3s - loss: 1.0127 - accuracy: 0.6606 - val_loss: 1.4860 - val_accuracy: 0.6230
#
# Epoch 00011: val_loss did not improve from 0.94736
# Epoch 12/100
# 1407/1407 - 3s - loss: 1.0065 - accuracy: 0.6610 - val_loss: 1.0183 - val_accuracy: 0.6622
#
# Epoch 00012: val_loss did not improve from 0.94736
# Epoch 13/100
# 1407/1407 - 3s - loss: 1.0272 - accuracy: 0.6559 - val_loss: 1.0121 - val_accuracy: 0.6666
#
# Epoch 00013: val_loss did not improve from 0.94736
# Epoch 14/100
# 1407/1407 - 3s - loss: 1.0417 - accuracy: 0.6533 - val_loss: 1.2036 - val_accuracy: 0.6374
#
# Epoch 00014: val_loss did not improve from 0.94736
# Epoch 15/100
# 1407/1407 - 3s - loss: 1.0542 - accuracy: 0.6482 - val_loss: 1.0676 - val_accuracy: 0.6400
#
# Epoch 00015: val_loss did not improve from 0.94736
# Epoch 16/100
# 1407/1407 - 3s - loss: 1.0772 - accuracy: 0.6444 - val_loss: 1.0010 - val_accuracy: 0.6736
#
# Epoch 00016: val_loss did not improve from 0.94736
# Epoch 17/100
# 1407/1407 - 3s - loss: 1.0929 - accuracy: 0.6400 - val_loss: 1.1354 - val_accuracy: 0.6098
#
# Epoch 00017: val_loss did not improve from 0.94736
# Epoch 18/100
# 1407/1407 - 3s - loss: 1.1122 - accuracy: 0.6332 - val_loss: 1.0910 - val_accuracy: 0.6426
#
# Epoch 00018: val_loss did not improve from 0.94736
# Epoch 19/100
# 1407/1407 - 3s - loss: 1.1337 - accuracy: 0.6258 - val_loss: 1.1553 - val_accuracy: 0.6202
#
# Epoch 00019: val_loss did not improve from 0.94736
# Epoch 20/100
# 1407/1407 - 3s - loss: 1.1457 - accuracy: 0.6201 - val_loss: 1.1179 - val_accuracy: 0.6504
#
# Epoch 00020: val_loss did not improve from 0.94736
# Epoch 21/100
# 1407/1407 - 3s - loss: 1.1568 - accuracy: 0.6203 - val_loss: 1.2399 - val_accuracy: 0.5684
#
# Epoch 00021: val_loss did not improve from 0.94736
# Epoch 22/100
# 1407/1407 - 3s - loss: 1.1758 - accuracy: 0.6114 - val_loss: 1.0885 - val_accuracy: 0.6234
#
# Epoch 00022: val_loss did not improve from 0.94736
# Epoch 23/100
# 1407/1407 - 3s - loss: 1.2011 - accuracy: 0.6041 - val_loss: 1.2802 - val_accuracy: 0.5736
#
# Epoch 00023: val_loss did not improve from 0.94736
# Epoch 24/100
# 1407/1407 - 3s - loss: 1.2181 - accuracy: 0.5991 - val_loss: 1.1125 - val_accuracy: 0.6136
#
# Epoch 00024: val_loss did not improve from 0.94736
# Epoch 25/100
# 1407/1407 - 3s - loss: 1.2304 - accuracy: 0.5933 - val_loss: 1.3987 - val_accuracy: 0.5478
#
# Epoch 00025: val_loss did not improve from 0.94736
# Epoch 26/100
# 1407/1407 - 3s - loss: 1.2530 - accuracy: 0.5922 - val_loss: 1.1010 - val_accuracy: 0.6346
#
# Epoch 00026: val_loss did not improve from 0.94736
# Epoch 27/100
# 1407/1407 - 3s - loss: 1.2644 - accuracy: 0.5842 - val_loss: 1.1504 - val_accuracy: 0.6308
#
# Epoch 00027: val_loss did not improve from 0.94736
# Epoch 28/100
# 1407/1407 - 3s - loss: 1.2730 - accuracy: 0.5801 - val_loss: 1.1442 - val_accuracy: 0.6088
#
# Epoch 00028: val_loss did not improve from 0.94736
# Epoch 29/100
# 1407/1407 - 3s - loss: 1.2911 - accuracy: 0.5735 - val_loss: 1.3386 - val_accuracy: 0.5244
#
# Epoch 00029: val_loss did not improve from 0.94736
# Epoch 30/100
# 1407/1407 - 3s - loss: 1.3071 - accuracy: 0.5704 - val_loss: 1.4442 - val_accuracy: 0.5616
#
# Epoch 00030: val_loss did not improve from 0.94736
# Epoch 31/100
# 1407/1407 - 3s - loss: 1.3084 - accuracy: 0.5671 - val_loss: 1.2955 - val_accuracy: 0.5858
#
# Epoch 00031: val_loss did not improve from 0.94736
# Epoch 32/100
# 1407/1407 - 3s - loss: 1.3260 - accuracy: 0.5617 - val_loss: 2.4485 - val_accuracy: 0.4154
#
# Epoch 00032: val_loss did not improve from 0.94736
# Epoch 33/100
# 1407/1407 - 3s - loss: 1.3408 - accuracy: 0.5549 - val_loss: 1.1864 - val_accuracy: 0.6144
#
# Epoch 00033: val_loss did not improve from 0.94736
# Epoch 34/100
# 1407/1407 - 3s - loss: 1.3451 - accuracy: 0.5518 - val_loss: 1.2296 - val_accuracy: 0.5728
#
# Epoch 00034: val_loss did not improve from 0.94736
# Epoch 35/100
# 1407/1407 - 3s - loss: 1.3679 - accuracy: 0.5456 - val_loss: 1.4029 - val_accuracy: 0.4880
#
# Epoch 00035: val_loss did not improve from 0.94736
# Epoch 36/100
# 1407/1407 - 3s - loss: 1.3946 - accuracy: 0.5371 - val_loss: 1.1855 - val_accuracy: 0.5870
#
# Epoch 00036: val_loss did not improve from 0.94736
# Epoch 37/100
# 1407/1407 - 3s - loss: 1.4020 - accuracy: 0.5372 - val_loss: 1.2450 - val_accuracy: 0.5878
#
# Epoch 00037: val_loss did not improve from 0.94736
# Epoch 38/100
# 1407/1407 - 3s - loss: 1.4138 - accuracy: 0.5336 - val_loss: 1.1912 - val_accuracy: 0.6244
#
# Epoch 00038: val_loss did not improve from 0.94736
# Epoch 39/100
# 1407/1407 - 3s - loss: 1.4521 - accuracy: 0.5196 - val_loss: 1.4398 - val_accuracy: 0.5480
#
# Epoch 00039: val_loss did not improve from 0.94736
# Epoch 40/100
# 1407/1407 - 3s - loss: 1.4721 - accuracy: 0.5133 - val_loss: 1.4842 - val_accuracy: 0.4968
#
# Epoch 00040: val_loss did not improve from 0.94736
# Epoch 41/100
# 1407/1407 - 3s - loss: 1.4874 - accuracy: 0.5053 - val_loss: 1.3624 - val_accuracy: 0.5284
#
# Epoch 00041: val_loss did not improve from 0.94736
# Epoch 42/100
# 1407/1407 - 3s - loss: 1.4799 - accuracy: 0.5072 - val_loss: 1.3348 - val_accuracy: 0.5154
#
# Epoch 00042: val_loss did not improve from 0.94736
# Epoch 43/100
# 1407/1407 - 3s - loss: 1.4930 - accuracy: 0.4983 - val_loss: 2.4048 - val_accuracy: 0.3872
#
# Epoch 00043: val_loss did not improve from 0.94736
# Epoch 44/100
# 1407/1407 - 3s - loss: 1.5195 - accuracy: 0.4936 - val_loss: 2.0491 - val_accuracy: 0.5286
#
# Epoch 00044: val_loss did not improve from 0.94736
# Epoch 45/100
# 1407/1407 - 3s - loss: 1.5338 - accuracy: 0.4874 - val_loss: 1.3504 - val_accuracy: 0.5452
#
# Epoch 00045: val_loss did not improve from 0.94736
# Epoch 46/100
# 1407/1407 - 3s - loss: 1.5481 - accuracy: 0.4823 - val_loss: 1.3994 - val_accuracy: 0.5298
#
# Epoch 00046: val_loss did not improve from 0.94736
# Epoch 47/100
# 1407/1407 - 3s - loss: 1.5601 - accuracy: 0.4736 - val_loss: 1.4886 - val_accuracy: 0.5514
#
# Epoch 00047: val_loss did not improve from 0.94736
# Epoch 48/100
# 1407/1407 - 3s - loss: 1.5549 - accuracy: 0.4766 - val_loss: 1.4987 - val_accuracy: 0.5076
#
# Epoch 00048: val_loss did not improve from 0.94736
# Epoch 49/100
# 1407/1407 - 3s - loss: 1.5639 - accuracy: 0.4746 - val_loss: 1.9626 - val_accuracy: 0.3700
#
# Epoch 00049: val_loss did not improve from 0.94736
# Epoch 50/100
# 1407/1407 - 3s - loss: 1.5825 - accuracy: 0.4623 - val_loss: 1.4751 - val_accuracy: 0.4722
#
# Epoch 00050: val_loss did not improve from 0.94736
# Epoch 51/100
# 1407/1407 - 3s - loss: 1.5952 - accuracy: 0.4636 - val_loss: 2.2486 - val_accuracy: 0.4900
#
# Epoch 00051: val_loss did not improve from 0.94736
# Epoch 52/100
# 1407/1407 - 3s - loss: 1.5939 - accuracy: 0.4612 - val_loss: 1.3904 - val_accuracy: 0.5420
#
# Epoch 00052: val_loss did not improve from 0.94736
# Epoch 53/100
# 1407/1407 - 3s - loss: 1.6411 - accuracy: 0.4489 - val_loss: 1.5276 - val_accuracy: 0.4520
#
# Epoch 00053: val_loss did not improve from 0.94736
# Epoch 54/100
# 1407/1407 - 3s - loss: 1.6310 - accuracy: 0.4469 - val_loss: 1.7756 - val_accuracy: 0.3886
#
# Epoch 00054: val_loss did not improve from 0.94736
# Epoch 55/100
# 1407/1407 - 3s - loss: 1.6424 - accuracy: 0.4452 - val_loss: 1.5079 - val_accuracy: 0.4602
#
# Epoch 00055: val_loss did not improve from 0.94736
# Epoch 56/100
# 1407/1407 - 3s - loss: 1.6412 - accuracy: 0.4427 - val_loss: 1.5553 - val_accuracy: 0.5018
#
# Epoch 00056: val_loss did not improve from 0.94736
# Epoch 57/100
# 1407/1407 - 3s - loss: 1.6525 - accuracy: 0.4349 - val_loss: 1.3473 - val_accuracy: 0.5188
#
# Epoch 00057: val_loss did not improve from 0.94736
# Epoch 58/100
# 1407/1407 - 3s - loss: 1.6479 - accuracy: 0.4414 - val_loss: 1.7432 - val_accuracy: 0.3348
#
# Epoch 00058: val_loss did not improve from 0.94736
# Epoch 59/100
# 1407/1407 - 3s - loss: 1.6538 - accuracy: 0.4382 - val_loss: 1.4825 - val_accuracy: 0.4928
#
# Epoch 00059: val_loss did not improve from 0.94736
# Epoch 60/100
# 1407/1407 - 3s - loss: 1.6688 - accuracy: 0.4234 - val_loss: 1.5532 - val_accuracy: 0.4446
#
# Epoch 00060: val_loss did not improve from 0.94736
# Epoch 61/100
# 1407/1407 - 3s - loss: 1.6570 - accuracy: 0.4283 - val_loss: 2.1846 - val_accuracy: 0.3592
#
# Epoch 00061: val_loss did not improve from 0.94736
# Epoch 62/100
# 1407/1407 - 3s - loss: 1.6739 - accuracy: 0.4270 - val_loss: 2.8104 - val_accuracy: 0.1894
#
# Epoch 00062: val_loss did not improve from 0.94736
# Epoch 63/100
# 1407/1407 - 3s - loss: 1.6782 - accuracy: 0.4252 - val_loss: 2.5649 - val_accuracy: 0.3438
#
# Epoch 00063: val_loss did not improve from 0.94736
# Epoch 64/100
# 1407/1407 - 3s - loss: 1.6787 - accuracy: 0.4216 - val_loss: 1.5081 - val_accuracy: 0.4644
#
# Epoch 00064: val_loss did not improve from 0.94736
# Epoch 65/100
# 1407/1407 - 3s - loss: 1.6849 - accuracy: 0.4233 - val_loss: 1.5749 - val_accuracy: 0.4096
#
# Epoch 00065: val_loss did not improve from 0.94736
# Epoch 66/100
# 1407/1407 - 3s - loss: 1.6803 - accuracy: 0.4199 - val_loss: 2.3437 - val_accuracy: 0.4258
#
# Epoch 00066: val_loss did not improve from 0.94736
# Epoch 67/100
# 1407/1407 - 3s - loss: 1.7063 - accuracy: 0.4136 - val_loss: 1.5617 - val_accuracy: 0.4378
#
# Epoch 00067: val_loss did not improve from 0.94736
# Epoch 68/100
# 1407/1407 - 3s - loss: 1.6942 - accuracy: 0.4142 - val_loss: 1.6548 - val_accuracy: 0.4046
#
# Epoch 00068: val_loss did not improve from 0.94736
# Epoch 69/100
# 1407/1407 - 3s - loss: 1.6941 - accuracy: 0.4102 - val_loss: 3.2812 - val_accuracy: 0.2774
#
# Epoch 00069: val_loss did not improve from 0.94736
# Epoch 70/100
# 1407/1407 - 3s - loss: 1.7034 - accuracy: 0.4146 - val_loss: 1.6090 - val_accuracy: 0.4222
#
# Epoch 00070: val_loss did not improve from 0.94736
# Epoch 71/100
# 1407/1407 - 3s - loss: 1.7134 - accuracy: 0.4062 - val_loss: 1.4392 - val_accuracy: 0.4850
#
# Epoch 00071: val_loss did not improve from 0.94736
# Epoch 72/100
# 1407/1407 - 3s - loss: 1.7192 - accuracy: 0.4054 - val_loss: 2.7869 - val_accuracy: 0.3350
#
# Epoch 00072: val_loss did not improve from 0.94736
# Epoch 73/100
# 1407/1407 - 3s - loss: 1.7206 - accuracy: 0.4051 - val_loss: 1.8132 - val_accuracy: 0.3830
#
# Epoch 00073: val_loss did not improve from 0.94736
# Epoch 74/100
# 1407/1407 - 3s - loss: 1.7147 - accuracy: 0.4022 - val_loss: 1.6760 - val_accuracy: 0.4148
#
# Epoch 00074: val_loss did not improve from 0.94736
# Epoch 75/100
# 1407/1407 - 3s - loss: 1.7295 - accuracy: 0.3975 - val_loss: 1.5228 - val_accuracy: 0.4446
#
# Epoch 00075: val_loss did not improve from 0.94736
# Epoch 76/100
# 1407/1407 - 3s - loss: 1.7444 - accuracy: 0.3979 - val_loss: 1.5882 - val_accuracy: 0.4380
#
# Epoch 00076: val_loss did not improve from 0.94736
# Epoch 77/100
# 1407/1407 - 3s - loss: 1.7483 - accuracy: 0.3906 - val_loss: 1.5585 - val_accuracy: 0.4486
#
# Epoch 00077: val_loss did not improve from 0.94736
# Epoch 78/100
# 1407/1407 - 3s - loss: 1.7798 - accuracy: 0.3803 - val_loss: 1.7840 - val_accuracy: 0.4046
#
# Epoch 00078: val_loss did not improve from 0.94736
# Epoch 79/100
# 1407/1407 - 3s - loss: 1.7814 - accuracy: 0.3734 - val_loss: 1.7956 - val_accuracy: 0.3578
#
# Epoch 00079: val_loss did not improve from 0.94736
# Epoch 80/100
# 1407/1407 - 3s - loss: 1.8022 - accuracy: 0.3676 - val_loss: 1.5358 - val_accuracy: 0.4380
#
# Epoch 00080: val_loss did not improve from 0.94736
# Epoch 81/100
# 1407/1407 - 3s - loss: 1.7985 - accuracy: 0.3681 - val_loss: 1.6274 - val_accuracy: 0.3896
#
# Epoch 00081: val_loss did not improve from 0.94736
# Epoch 82/100
# 1407/1407 - 3s - loss: 1.8151 - accuracy: 0.3606 - val_loss: 2.1527 - val_accuracy: 0.3166
#
# Epoch 00082: val_loss did not improve from 0.94736
# Epoch 83/100
# 1407/1407 - 3s - loss: 1.7905 - accuracy: 0.3668 - val_loss: 1.6018 - val_accuracy: 0.4184
#
# Epoch 00083: val_loss did not improve from 0.94736
# Epoch 84/100
# 1407/1407 - 3s - loss: 1.8060 - accuracy: 0.3624 - val_loss: 1.5217 - val_accuracy: 0.4446
#
# Epoch 00084: val_loss did not improve from 0.94736
# Epoch 85/100
# 1407/1407 - 3s - loss: 1.8025 - accuracy: 0.3682 - val_loss: 1.7823 - val_accuracy: 0.3476
#
# Epoch 00085: val_loss did not improve from 0.94736
# Epoch 86/100
# 1407/1407 - 3s - loss: 1.8120 - accuracy: 0.3594 - val_loss: 1.5882 - val_accuracy: 0.4046
#
# Epoch 00086: val_loss did not improve from 0.94736
# Epoch 87/100
# 1407/1407 - 3s - loss: 1.8055 - accuracy: 0.3551 - val_loss: 1.5893 - val_accuracy: 0.4266
#
# Epoch 00087: val_loss did not improve from 0.94736
# Epoch 88/100
# 1407/1407 - 3s - loss: 1.8086 - accuracy: 0.3598 - val_loss: 1.5996 - val_accuracy: 0.4150
#
# Epoch 00088: val_loss did not improve from 0.94736
# Epoch 89/100
# 1407/1407 - 3s - loss: 1.8012 - accuracy: 0.3617 - val_loss: 1.7098 - val_accuracy: 0.3806
#
# Epoch 00089: val_loss did not improve from 0.94736
# Epoch 90/100
# 1407/1407 - 3s - loss: 1.8021 - accuracy: 0.3564 - val_loss: 2.1445 - val_accuracy: 0.3426
#
# Epoch 00090: val_loss did not improve from 0.94736
# Epoch 91/100
# 1407/1407 - 3s - loss: 1.7845 - accuracy: 0.3597 - val_loss: 2.7775 - val_accuracy: 0.2964
#
# Epoch 00091: val_loss did not improve from 0.94736
# Epoch 92/100
# 1407/1407 - 3s - loss: 1.8087 - accuracy: 0.3587 - val_loss: 2.2906 - val_accuracy: 0.3386
#
# Epoch 00092: val_loss did not improve from 0.94736
# Epoch 93/100
# 1407/1407 - 3s - loss: 1.8252 - accuracy: 0.3508 - val_loss: 1.6895 - val_accuracy: 0.3636
#
# Epoch 00093: val_loss did not improve from 0.94736
# Epoch 94/100
# 1407/1407 - 3s - loss: 1.8229 - accuracy: 0.3564 - val_loss: 1.5640 - val_accuracy: 0.4476
#
# Epoch 00094: val_loss did not improve from 0.94736
# Epoch 95/100
# 1407/1407 - 3s - loss: 1.8294 - accuracy: 0.3525 - val_loss: 2.0548 - val_accuracy: 0.2940
#
# Epoch 00095: val_loss did not improve from 0.94736
# Epoch 96/100
# 1407/1407 - 3s - loss: 1.8182 - accuracy: 0.3486 - val_loss: 1.8375 - val_accuracy: 0.3064
#
# Epoch 00096: val_loss did not improve from 0.94736
# Epoch 97/100
# 1407/1407 - 3s - loss: 1.8326 - accuracy: 0.3475 - val_loss: 2.8857 - val_accuracy: 0.3786
#
# Epoch 00097: val_loss did not improve from 0.94736
# Epoch 98/100
# 1407/1407 - 3s - loss: 1.8249 - accuracy: 0.3426 - val_loss: 1.6363 - val_accuracy: 0.4400
#
# Epoch 00098: val_loss did not improve from 0.94736
# Epoch 99/100
# 1407/1407 - 3s - loss: 1.8202 - accuracy: 0.3466 - val_loss: 1.6317 - val_accuracy: 0.4344
#
# Epoch 00099: val_loss did not improve from 0.94736
# Epoch 100/100
# 1407/1407 - 3s - loss: 1.8337 - accuracy: 0.3440 - val_loss: 2.2230 - val_accuracy: 0.3914
#
# Epoch 00100: val_loss did not improve from 0.94736

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.3977000117301941

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
